# %% [markdown]
# # Introduction to Python
#
# ## Objective
#
# To understand basic Python syntax and demonstrate the use of variables, data types, user input, arithmetic operators, and output.
#
# ## Concepts Covered
#
# - Variables and assignment
# - Basic data types
# - User input
# - Type conversion
# - Arithmetic operators
# - Output using `print()`

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

next_year_age = age + 1

print("\nHello,", name)
print("You are currently", age, "years old.")
print("Next year, you will be", next_year_age, "years old.")
# Out:
# Hello, Haniya
# You are currently 21 years old.
# Next year, you will be 22 years old.
